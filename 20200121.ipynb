# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
data = pd.read_csv('usedCar_Dataset.csv')

# %%
data = data.drop(columns=['CarID'])

# %%
data.head()
# Out:
#   MakeId                                              Title     BodyStyle Rental       Location GasMileage_city GasMileage_highway    Price   Mileage    Transmission  FuelType ExteriorColor InteriorColor DoorsNum MaximumSeating Engine         Drivetrain                VIN  OptionCount                                       MajorOptions Certified  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 0     m1                     2007 Chevrolet Tahoe - $11,999           suv    NaN    Garland, TX             NaN                NaN  11999.0  129280.0       Automatic  Gasoline          Gold           NaN      NaN            NaN     V8                NaN  1GNFC13J47R120389            0                                                NaN       NaN             0.0               2.0         1873      12999.0
# ...

# %%
data = data.drop(columns=['VIN','Certified'])

# %%
data.head()
# Out:
#   MakeId                                              Title     BodyStyle Rental       Location GasMileage_city GasMileage_highway    Price   Mileage    Transmission  FuelType ExteriorColor InteriorColor DoorsNum MaximumSeating Engine         Drivetrain  OptionCount                                       MajorOptions  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 0     m1                     2007 Chevrolet Tahoe - $11,999           suv    NaN    Garland, TX             NaN                NaN  11999.0  129280.0       Automatic  Gasoline          Gold           NaN      NaN            NaN     V8                NaN            0                                                NaN             0.0               2.0         1873      12999.0
# ...

# %%
data.iloc[:,[0,1]]
# Out:
#         MakeId                                              Title
# 0           m1                     2007 Chevrolet Tahoe - $11,999
# 1           m1                   2005 Chevrolet Express - $11,995
# 2           m1  2010 Chevrolet Silverado 2500HD Work Truck Ext...
# 3           m1  2014 Chevrolet Corvette Stingray 3LT Coupe RWD...
# 4           m1         2002 Chevrolet Monte Carlo SS FWD - $3,440
# ...        ...                                                ...
# 2375345    m98         2012 FIAT 500 Lounge Convertible - $15,100
# 2375346    m98                                2013 FIAT 500 Sport
# 2375347    m98                               2012 FIAT 500 Lounge
# 2375348    m98                               2013 FIAT 500 Lounge
# 2375349    m98                                2013 FIAT 500 Sport
#
# [2375350 rows x 2 columns]

# %%
data['MakeId'].unique()
# Out:
# array(['m1', 'm110', 'm111', 'm112', 'm12', 'm124', 'm135', 'm2', 'm141',
#        'm19', 'm191', 'm24', 'm194', 'm20', 'm203', 'm21', 'm22', 'm23',
#        'm25', 'm26', 'm27', 'm79', 'm28', 'm3', 'm30', 'm31', 'm32',
#        'm33', 'm34', 'm35', 'm37', 'm38', 'm4', 'm40', 'm42', 'm43',
#        'm44', 'm45', 'm46', 'm47', 'm48', 'm49', 'm50', 'm51', 'm52',
#        'm53', 'm54', 'm55', 'm56', 'm6', 'm7', 'm84', 'm85', 'm87', 'm98'],
#       dtype=object)

# %%
len(data['MakeId'].unique())
# Out:
# 55

# %%
data.groupby(by='MakeId').mean()
# Out:
#                 Price        Mileage  OptionCount  Accident Check  OwnershipHistory  SellingDays   OriginPrice
# MakeId
# m1       20552.448054   70103.877260     3.785969        0.202338          1.713811    77.852739  2.318317e+04
# m110    111837.779221   17868.043408     3.192488        0.070147          2.522604   148.286385  1.274075e+05
# m111      7761.775044   43133.327212     1.344262        0.158416          1.970199    87.685246  8.708980e+03
# m112     54441.267855   35342.807218     6.490385        0.150927          1.427690    59.061189  5.719765e+04
# m12      15612.853496   56238.555903     2.889740        0.215436          1.519313    67.737550  1.765443e+04
# m124     33040.650542   19035.654098     6.346677        0.059113          1.225893   103.728583  3.694086e+04
# m135    104517.280899    8438.387500     0.000000             NaN               NaN   209.638298  7.969852e+04
# ...

# %%
data.groupby(by='MakeId').agg({'Price':'mean'}).sort_values(by=['Price'], ascending=False)
# groupby(by='MakeId') : 根據 MakeID 分組
# agg({'Price':'mean'}) 計算每一組 Price 的 mean
# sort_values(by=['Price'] : 根據 Price 排序
# ascending=False : 由大排到小
# Out:
#                 Price
# MakeId
# m141    242590.988764
# m34     234485.642857
# m25     207182.946649
# m49     176183.553633
# m110    111837.779221
# m135    104517.280899
# m20     101485.002327
# m194     96099.351351
# m48      63659.688463
# m112     54441.267855
# m40      42315.690202
# m35      38766.782925
# m87      38100.861930
# m79      34988.000000
# m203     33361.386755
# m124     33040.650542
# m31      30826.836909
# m43      29837.611710
# m191     28994.538222
# m19      26719.629145
# m3       26288.370084
# m26      25703.389552
# m22      24816.472077
# m37      24342.104459
# m84      22885.779173
# m56      22126.041932
# m38      22116.812928
# m32      21524.517946
# m4       20779.365121
# m2       20645.969288
# m1       20552.448054
# m7       18716.774606
# m53      18316.158247
# m27      17663.801468
# m24      17554.444607
# m21      16382.299273
# m6       15764.914016
# m42      15613.826273
# m12      15612.853496
# m45      15336.221773
# ...

# %%
data.groupby(by='MakeId').size()
# Out:
# MakeId
# m1      293079
# m110       639
# m111       610
# m112      1144
# m12     167186
# m124      1249
# m135        94
# m141       483
# m19      40281
# m191     76643
# m194        40
# m2      329590
# m20       1596
# m203      1146
# m21      35364
# m22      37894
# m23      38940
# m24     106549
# m25       1870
# m26      99698
# m27       2110
# m28      96737
# m3       78226
# m30        249
# m31       6989
# m32     138695
# m33      68444
# m34        691
# m35      14283
# m37      49712
# m38      21555
# m4       24941
# m40       2774
# m42      32988
# m43      72802
# m44       3307
# m45      10680
# m46      13522
# m47       6474
# m48      15158
# m49        629
# m50        872
# m51       3205
# m52       4682
# m53      48757
# m54        917
# m55      58642
# m56      13177
# m6      122921
# m7      192976
# m79          1
# m84      28800
# m85        799
# m87        405
# m98       4135
# dtype: int64

# %%
car_brand = data.groupby(by='MakeId').agg({'Price':'mean'})

# %%
car_brand['number_of_cars'] = data.groupby(by='MakeId').size()

# %%
car_brand.sort_values(by=['Price'], ascending=False)
# Out:
#                 Price  number_of_cars
# MakeId
# m141    242590.988764             483
# m34     234485.642857             691
# m25     207182.946649            1870
# m49     176183.553633             629
# m110    111837.779221             639
# m135    104517.280899              94
# m20     101485.002327            1596
# m194     96099.351351              40
# m48      63659.688463           15158
# m112     54441.267855            1144
# m40      42315.690202            2774
# m35      38766.782925           14283
# m87      38100.861930             405
# m79      34988.000000               1
# m203     33361.386755            1146
# m124     33040.650542            1249
# m31      30826.836909            6989
# m43      29837.611710           72802
# m191     28994.538222           76643
# m19      26719.629145           40281
# m3       26288.370084           78226
# m26      25703.389552           99698
# m22      24816.472077           37894
# ...

# %%
data[data['MakeId']=='m79']
# Out:
#         MakeId                                Title BodyStyle Rental     Location GasMileage_city GasMileage_highway    Price  Mileage Transmission FuelType ExteriorColor InteriorColor DoorsNum MaximumSeating Engine Drivetrain  OptionCount MajorOptions  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 1235578    m79  1993 AM General Hummer H1 - $34,988       suv    NaN  Garland, TX             NaN                NaN  34988.0  94302.0    Automatic      NaN         White   Brown (Tan)      NaN            NaN    NaN        NaN            0          NaN             0.0               4.0           27      39988.0

# %%
data[data['MakeId']=='m87']
# Out:
#         MakeId                                              Title    BodyStyle Rental                    Location GasMileage_city GasMileage_highway     Price   Mileage       Transmission           FuelType                            ExteriorColor               InteriorColor DoorsNum MaximumSeating                Engine         Drivetrain  OptionCount                                       MajorOptions  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 2370810    m87                      1999 Plymouth Breeze - $1,495        sedan    NaN                  Deland, FL             NaN                NaN    1495.0  141877.0          Automatic           Gasoline                                     Gold                        Gold      NaN            NaN                    I4                NaN            0                                                NaN             0.0               2.0         1782       3795.0
# ...

# %%
# 跑車
# m191 McLaren
# m34  Lamborghini
# m25 Ferrari
# m49 Rolls-Royce 勞斯萊斯
# m110 Aston Martin 奧斯頓·馬丁
# m135 Shelby Cobra 眼鏡蛇

# m20 Bentley Continental 賓利 Continental (賓利 Continental 原先屬於勞斯萊斯 , 後轉給大眾)
# m194 SRT Viper (Dodge Viper 道奇毒蛇)


# m48 Porsche 911 保時捷911
# m112 Tesla
# m40 Maserati 瑪莎拉蒂

# 從 m191 到 m40 多少可以歸類在跑車這一類(其中Tesla算是例外, 不是跑車但平均價格頗高)

# m35 Land Rover (英國的全地形車和運動型多用途車品牌) (Land Rover 台灣: 豪華轎車、運動、 四輪驅動車)

# %%
data = data.drop(index=1235578)
# m79 只有一筆資料,將他拿掉

# %%
data[data['MakeId']=='m79']
# Out:
# Empty DataFrame
# Columns: [MakeId, Title, BodyStyle, Rental, Location, GasMileage_city, GasMileage_highway, Price, Mileage, Transmission, FuelType, ExteriorColor, InteriorColor, DoorsNum, MaximumSeating, Engine, Drivetrain, OptionCount, MajorOptions, Accident Check, OwnershipHistory, SellingDays, OriginPrice]
# Index: []

# %%
car_brand = data.groupby(by='MakeId').agg({'Price':'mean'})
car_brand['number_of_cars'] = data.groupby(by='MakeId').size()

# %%
car_brand.sort_values(by=['Price'], ascending=False)
# Out:
#                 Price  number_of_cars
# MakeId
# m141    242590.988764             483
# m34     234485.642857             691
# m25     207182.946649            1870
# m49     176183.553633             629
# m110    111837.779221             639
# m135    104517.280899              94
# m20     101485.002327            1596
# m194     96099.351351              40
# m48      63659.688463           15158
# m112     54441.267855            1144
# m40      42315.690202            2774
# m35      38766.782925           14283
# m87      38100.861930             405
# m203     33361.386755            1146
# m124     33040.650542            1249
# m31      30826.836909            6989
# m43      29837.611710           72802
# m191     28994.538222           76643
# m19      26719.629145           40281
# m3       26288.370084           78226
# m26      25703.389552           99698
# m22      24816.472077           37894
# m37      24342.104459           49712
# ...

# %%
car_m141 = data[data['MakeId'] == 'm141']

# %%
car_m141.isnull().sum()
# Out:
# MakeId                  0
# Title                   0
# BodyStyle              17
# Rental                483
# Location                0
# GasMileage_city       334
# GasMileage_highway    334
# Price                  38
# Mileage                10
# Transmission            8
# FuelType                0
# ExteriorColor           9
# InteriorColor          46
# DoorsNum              369
# MaximumSeating         17
# Engine                  0
# Drivetrain             17
# OptionCount             0
# MajorOptions           43
# Accident Check         31
# OwnershipHistory       96
# SellingDays             0
# OriginPrice           196
# dtype: int64

# %%
car_m141
# Out:
#        MakeId                                              Title    BodyStyle Rental                Location GasMileage_city GasMileage_highway      Price  Mileage         Transmission  FuelType                        ExteriorColor                                      InteriorColor DoorsNum MaximumSeating Engine        Drivetrain  OptionCount                                       MajorOptions  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 465125   m141                           2016 McLaren 675LT Coupe        coupe    NaN       Pompano Beach, FL             NaN                NaN        NaN   2469.0    7-Speed Automatic  Gasoline                         Napier Green                                       Carbon Black      NaN        2 seats     V8  Rear-Wheel Drive            2                        Navigation System,Bluetooth             0.0               2.0         1215          NaN
# ...

# %%
car_m141['MaximumSeating'].unique()
# Out:
# array(['2 seats', nan], dtype=object)

# %%
car_m141[car_m141['MaximumSeating'].isnull()]
# Out:
#        MakeId                         Title BodyStyle Rental            Location GasMileage_city GasMileage_highway     Price  Mileage         Transmission  FuelType   ExteriorColor                                    InteriorColor DoorsNum MaximumSeating Engine Drivetrain  OptionCount                                       MajorOptions  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# 465144   m141  2018 McLaren 720S - $249,900       NaN    NaN      Boca Raton, FL             NaN                NaN  249900.0   5372.0    7-Speed Automatic  Gasoline  McLaren Orange                                      Caron Black      NaN            NaN     V8        NaN            5  Bluetooth,Leather Seats,Backup Camera,Aluminum...             0.0               NaN          417          NaN
# ...

# %%
car_m141.corr()
# Out:
#                      Price   Mileage  OptionCount  Accident Check  OwnershipHistory  SellingDays  OriginPrice
# Price             1.000000 -0.279216    -0.226608       -0.051965         -0.168611     0.029045     0.995311
# Mileage          -0.279216  1.000000     0.140138        0.149691          0.447395    -0.024906    -0.295935
# OptionCount      -0.226608  0.140138     1.000000        0.003461          0.048716     0.037292    -0.170657
# Accident Check   -0.051965  0.149691     0.003461        1.000000          0.095464    -0.029161    -0.062205
# OwnershipHistory -0.168611  0.447395     0.048716        0.095464          1.000000     0.102080    -0.148884
# SellingDays       0.029045 -0.024906     0.037292       -0.029161          0.102080     1.000000     0.036044
# OriginPrice       0.995311 -0.295935    -0.170657       -0.062205         -0.148884     0.036044     1.000000

# %%
data[data['Price'].isnull()].iloc[:,[7,-1]].isnull().sum()
# Out:
# Price          128142
# OriginPrice    124841
# dtype: int64
